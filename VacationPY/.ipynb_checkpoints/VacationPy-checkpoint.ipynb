# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import os 
import csv

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
geoapify_key
# Out:
# 'a116b51fb7b842909a4fcc477d3f4009'

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("citiesUpdate.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID           City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0           mitu   1.1983  -70.1733     23.81        91          19
# 1        1  haiku-pauwela  20.9219 -156.3051     31.01        51          40
# 2        2     al ghayzah  16.2079   52.1760     22.24        67           8
# 3        3         albany  42.6001  -73.9662      8.43        90         100
# 4        4         uturoa -16.7333 -151.4333     27.05        80          22
#
#    Wind Speed Country        Date
# 0        0.60      CO  1702254452
# 1        7.20      US  1702254847
# 2        2.91      YE  1702254848
# 3        1.79      US  1702254771
# 4       10.09      PF  1702254848

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
mapplot1 = city_data_df.hvplot.points("Lng", "Lat", geo = True, tiles = "OSM", color = "City", size = "Humidity")

# Display the map
mapplot1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
#idea weather condition 
#cloudiness 0
#humidity < 80
#windspeed < 3

idealDF = city_data_df.loc[(city_data_df['Cloudiness'] == 0) & (city_data_df['Wind Speed']<3)&(city_data_df['Humidity']<80)]
idealDF.dropna()
# Drop any rows with null values
# YOUR CODE HERE

# Display sample data
idealDF
# Out:
#      City_ID                        City      Lat       Lng  Max Temp  \
# 53        53                san patricio  28.0170  -97.5169     14.92
# 83        83                    waitangi -43.9535 -176.5597     11.64
# 103      103                      lompoc  34.6391 -120.4579     19.32
# 163      163                   dalbandin  28.8947   64.4101     11.32
# 168      168                    coquimbo -29.9533  -71.3436     16.85
# 213      213                       crane  31.3974 -102.3501      8.87
# 230      230                       nagqu  31.5000   92.0000    -14.07
# 255      255  san sebastian de la gomera  28.0916  -17.1133     24.53
# 283      283                    ghadamis  30.1337    9.5007      9.96
# 286      286                      badger  64.8000 -147.5333    -23.69
# 328      328                        tura  25.5198   90.2201     13.99
# 479      479        bellaria-igea marina  44.1421   12.4700      8.32
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = idealDF.copy()
hotel_df
del hotel_df["Cloudiness"]
del hotel_df["Wind Speed"]
del hotel_df["Date"]
del hotel_df['City_ID']


# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name']= " "


# Display sample data
hotel_df
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# 53                 san patricio  28.0170  -97.5169     14.92        27
# 83                     waitangi -43.9535 -176.5597     11.64        59
# 103                      lompoc  34.6391 -120.4579     19.32        49
# 163                   dalbandin  28.8947   64.4101     11.32        27
# 168                    coquimbo -29.9533  -71.3436     16.85        77
# 213                       crane  31.3974 -102.3501      8.87        23
# 230                       nagqu  31.5000   92.0000    -14.07        47
# 255  san sebastian de la gomera  28.0916  -17.1133     24.53        25
# 283                    ghadamis  30.1337    9.5007      9.96        56
# 286                      badger  64.8000 -147.5333    -23.69        73
# 328                        tura  25.5198   90.2201     13.99        62
# 479        bellaria-igea marina  44.1421   12.4700      8.32        76
# ...

# %%
url = "https://api.geoapify.com/v2/places"
params = {
    "categories" : "accommodation",
    "apiKey" : geoapify_key ,
    "limit" : 20,
    "filter" : f'circle:23.4167,-19.9833,10000',
    "bias": f'proximity:23.4167,-19.9833'
}

name_address1 = requests.get(url, params = params)
name_address1 = name_address1.json()
name_address1['features'][0]['properties']['name']
# Out:
# 'Center Lodge Conference Center'

# %%
geoapify_key
# Out:
# 'a116b51fb7b842909a4fcc477d3f4009'

# %%
params
# Out:
# {'categories': 'accommodation',
#  'apiKey': 'a116b51fb7b842909a4fcc477d3f4009',
#  'limit': 20,
#  'filter': 'circle:23.4167,-19.9833,10000',
#  'bias': 'proximity:23.4167,-19.9833'}

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories" : "accommodation",
    "apiKey" : geoapify_key,
    "limit" : 20
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = row["Lat"]
    longitude = row["Lng"]
    #print(latitude)
    #print(longitude)
    #print(radius)
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    #print(params["filter"])
    #print(params['bias'])
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = requests.get(base_url, params = params).json()
    #print(name_address)
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# san patricio - nearest hotel: No hotel found
# waitangi - nearest hotel: Travelers Rest
# lompoc - nearest hotel: Alano Club
# dalbandin - nearest hotel: SF Al-dawood Restaurant
# coquimbo - nearest hotel: Residencial La Esperanza
# crane - nearest hotel: No hotel found
# nagqu - nearest hotel: Naqu Hotel
# san sebastian de la gomera - nearest hotel: Hotel Villa Gomera
# ghadamis - nearest hotel: فندق عين الفارس
# badger - nearest hotel: Hotel North Pole
# tura - nearest hotel: No hotel found
# bellaria-igea marina - nearest hotel: morena
# canton - nearest hotel: No hotel found
# mesquite - nearest hotel: Holiday Inn Express & Suites
# usta muhammad - nearest hotel: No hotel found
# guskhara - nearest hotel: Guskara Municipal Lodge
# dhulikhel - nearest hotel: Royal Guesthouse
# el granada - nearest hotel: Beach House
# nacogdoches - nearest hotel: No hotel found
# nuevo ideal - nearest hotel: No hotel found
# bikaner - nearest hotel: The Prince Haveli
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
mapplot2 = hotel_df.hvplot.points("Lng", "Lat", geo = True, tiles = "OSM", color = "City", 
                                  hover_cols=['City', 'Max Temp', 'Hotel Name', 'Humidity', 'Country'])
mapplot2

# Display the map
# YOUR CODE HERE
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Hotel Name,Humidity,Country)
