# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import os 
import csv

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("citiesUpdate.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  papatowai -46.5619  169.4708    283.91        61          40
# 1        1   wildwood  38.5828  -90.6629    280.68        47           0
# 2        2       lebu -37.6167  -73.6500    286.71        85          96
# 3        3  daulatpur  26.5015   67.9706    290.97        23          79
# 4        4    al jawf  29.5000   38.7500    289.59        82          97
#
#    Wind Speed Country        Date  Max Temp C
# 0        9.12      NZ  1702340501       10.76
# 1        2.06      US  1702340216        7.53
# 2        2.60      CL  1702340502       13.56
# 3        1.29      PK  1702340502       17.82
# 4        0.68      SA  1702340502       16.44

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
mapplot1 = city_data_df.hvplot.points("Lng", "Lat", geo = True, tiles = "OSM", color = "City", size = "Humidity")

# Display the map
mapplot1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
#idea weather condition 
#cloudiness 0
#humidity < 80
#windspeed < 3

idealDF = city_data_df.loc[(city_data_df['Cloudiness'] == 0) & (city_data_df['Wind Speed']<3)&(city_data_df['Humidity']<80)]
idealDF.dropna()
# Drop any rows with null values
# YOUR CODE HERE

# Display sample data
idealDF
# Out:
#      City_ID                  City      Lat       Lng  Max Temp  Humidity  \
# 1          1              wildwood  38.5828  -90.6629    280.68        47
# 7          7             berezovyy  51.6667  135.7000    249.01        65
# 17        17                 lahan  26.7296   86.4951    288.40        64
# 109      109              calvinia -31.4707   19.7760    287.39        52
# 130      130       remire-montjoly   4.9167  -52.2667    301.17        78
# 183      183               matoury   4.8483  -52.3317    301.13        78
# 184      184       piton saint-leu -21.2196   55.3151    295.19        78
# 190      190          saint-pierre -21.3393   55.4781    295.69        78
# 191      191            long beach  33.7670 -118.1892    296.83        64
# 196      196             carnarvon -24.8667  113.6333    300.09        43
# 201      201        margaret river -33.9500  115.0667    295.09        52
# 211      211                 doaba  33.4244   70.7364    281.28        33
# 223      223                gilmer  32.7287  -94.9424    284.49        37
# 268      268                kodiak  57.7900 -152.4072    271.88        64
# 273      273                laguna  38.4210 -121.4238    289.32        47
# 275      275              hamilton  39.1834  -84.5333    275.36        76
# 276      276        cabo san lucas  22.8909 -109.9124    298.49        65
# 309      309  eldorado at santa fe  35.5264 -105.9347    278.12        52
# 338      338                  arar  30.9753   41.0381    291.16        25
# 339      339        north tamworth -31.0778  150.9261    303.21        42
# 368      368                 yasuj  30.6682   51.5880    273.90        51
# 374      374                illizi  26.4833    8.4667    283.04        36
# 414      414                  ghat  24.9647   10.1728    284.97        38
# 456      456              narrabri -30.3167  149.7833    304.00        43
# 504      504              bethanie -26.4833   17.1500    292.60        35
# 523      523                 houma  29.5958  -90.7195    283.71        57
#
#      Cloudiness  Wind Speed Country        Date  Max Temp C
# 1             0        2.06      US  1702340216        7.53
# 7             0        2.27      RU  1702340504      -24.14
# 17            0        1.62      NP  1702340508       15.25
# 109           0        2.82      ZA  1702340542       14.24
# 130           0        2.06      GF  1702340551       28.02
# 183           0        2.06      GF  1702340570       27.98
# 184           0        2.57      RE  1702340571       22.04
# 190           0        2.57      RE  1702340573       22.54
# 191           0        2.57      US  1702340361       23.68
# 196           0        1.14      AU  1702340389       26.94
# 201           0        2.96      AU  1702340577       21.94
# 211           0        1.05      PK  1702340580        8.13
# 223           0        0.00      US  1702340584       11.34
# 268           0        2.57      US  1702340573       -1.27
# 273           0        2.06      US  1702340344       16.17
# 275           0        1.79      US  1702340398        2.21
# 276           0        2.06      MX  1702340395       25.34
# 309           0        0.45      US  1702340619        4.97
# 338           0        2.06      SA  1702340629       18.01
# 339           0        2.57      AU  1702340629       30.06
# 368           0        0.00      IR  1702340640        0.75
# 374           0        2.53      DZ  1702340642        9.89
# 414           0        1.66      LY  1702340658       11.82
# 456           0        0.89      AU  1702340701       30.85
# 504           0        2.49     NaN  1702340722       19.45
# 523           0        0.00      US  1702340704       10.56

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = idealDF.copy()
hotel_df
del hotel_df["Cloudiness"]
del hotel_df["Wind Speed"]
del hotel_df["Date"]
del hotel_df['City_ID']


# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name']= " "


# Display sample data
hotel_df
# Out:
#                      City      Lat       Lng  Max Temp  Humidity Country  \
# 1                wildwood  38.5828  -90.6629    280.68        47      US
# 7               berezovyy  51.6667  135.7000    249.01        65      RU
# 17                  lahan  26.7296   86.4951    288.40        64      NP
# 109              calvinia -31.4707   19.7760    287.39        52      ZA
# 130       remire-montjoly   4.9167  -52.2667    301.17        78      GF
# 183               matoury   4.8483  -52.3317    301.13        78      GF
# 184       piton saint-leu -21.2196   55.3151    295.19        78      RE
# 190          saint-pierre -21.3393   55.4781    295.69        78      RE
# 191            long beach  33.7670 -118.1892    296.83        64      US
# 196             carnarvon -24.8667  113.6333    300.09        43      AU
# 201        margaret river -33.9500  115.0667    295.09        52      AU
# 211                 doaba  33.4244   70.7364    281.28        33      PK
# 223                gilmer  32.7287  -94.9424    284.49        37      US
# 268                kodiak  57.7900 -152.4072    271.88        64      US
# 273                laguna  38.4210 -121.4238    289.32        47      US
# 275              hamilton  39.1834  -84.5333    275.36        76      US
# 276        cabo san lucas  22.8909 -109.9124    298.49        65      MX
# 309  eldorado at santa fe  35.5264 -105.9347    278.12        52      US
# 338                  arar  30.9753   41.0381    291.16        25      SA
# 339        north tamworth -31.0778  150.9261    303.21        42      AU
# 368                 yasuj  30.6682   51.5880    273.90        51      IR
# 374                illizi  26.4833    8.4667    283.04        36      DZ
# 414                  ghat  24.9647   10.1728    284.97        38      LY
# 456              narrabri -30.3167  149.7833    304.00        43      AU
# 504              bethanie -26.4833   17.1500    292.60        35     NaN
# 523                 houma  29.5958  -90.7195    283.71        57      US
#
#      Max Temp C Hotel Name
# 1          7.53
# 7        -24.14
# 17        15.25
# 109       14.24
# 130       28.02
# 183       27.98
# 184       22.04
# 190       22.54
# 191       23.68
# 196       26.94
# 201       21.94
# 211        8.13
# 223       11.34
# 268       -1.27
# 273       16.17
# 275        2.21
# 276       25.34
# 309        4.97
# 338       18.01
# 339       30.06
# 368        0.75
# 374        9.89
# 414       11.82
# 456       30.85
# 504       19.45
# 523       10.56

# %%
#find hotel within 10,000 m 
url = "https://api.geoapify.com/v2/places"
params = {
    "categories" : "accommodation",
    "apiKey" : geoapify_key ,
    "limit" : 20,
    "filter" : f'circle:23.4167,-19.9833,10000',
    "bias": f'proximity:23.4167,-19.9833'
}

name_address1 = requests.get(url, params = params)
name_address1 = name_address1.json()
name_address1['features'][0]['properties']['name']
# Out:
# 'Center Lodge Conference Center'

# %%
params
# Out:
# {'categories': 'accommodation',
#  'apiKey': 'a116b51fb7b842909a4fcc477d3f4009',
#  'limit': 20,
#  'filter': 'circle:23.4167,-19.9833,10000',
#  'bias': 'proximity:23.4167,-19.9833'}

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories" : "accommodation",
    "apiKey" : geoapify_key,
    "limit" : 20
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = row["Lat"]
    longitude = row["Lng"]
    #print(latitude)
    #print(longitude)
    #print(radius)
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    #print(params["filter"])
    #print(params['bias'])
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = requests.get(base_url, params = params).json()
    #print(name_address)
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# wildwood - nearest hotel: Wildwood Hotel
# berezovyy - nearest hotel: No hotel found
# lahan - nearest hotel: Shrawan ke Room
# calvinia - nearest hotel: Hantam Huis
# remire-montjoly - nearest hotel: Motel du Lac
# matoury - nearest hotel: Casa Blanca
# piton saint-leu - nearest hotel: Les Lataniers
# saint-pierre - nearest hotel: Tropic Hotel
# long beach - nearest hotel: Westin
# carnarvon - nearest hotel: Carnarvon Motel
# margaret river - nearest hotel: No hotel found
# doaba - nearest hotel: No hotel found
# gilmer - nearest hotel: No hotel found
# kodiak - nearest hotel: Russian Heritage Inn
# laguna - nearest hotel: Holiday Inn Express & Suites
# hamilton - nearest hotel: North Vista Manor
# cabo san lucas - nearest hotel: Comfort Rooms
# eldorado at santa fe - nearest hotel: No hotel found
# arar - nearest hotel: دار أوتيل Dar Otel
# north tamworth - nearest hotel: Imperial Brew House
# yasuj - nearest hotel: خوابگاه دانشجویی آمود
# illizi - nearest hotel: بوناقة
# ghat - nearest hotel: فندق تاسيلي
# narrabri - nearest hotel: Aaron Inn Motel
# bethanie - nearest hotel: Bethanie Guest House
# houma - nearest hotel: Courtyard by Marriott Houma
#                      City      Lat       Lng  Max Temp  Humidity Country  \
# 1                wildwood  38.5828  -90.6629    280.68        47      US
# 7               berezovyy  51.6667  135.7000    249.01        65      RU
# 17                  lahan  26.7296   86.4951    288.40        64      NP
# 109              calvinia -31.4707   19.7760    287.39        52      ZA
# 130       remire-montjoly   4.9167  -52.2667    301.17        78      GF
# 183               matoury   4.8483  -52.3317    301.13        78      GF
# 184       piton saint-leu -21.2196   55.3151    295.19        78      RE
# 190          saint-pierre -21.3393   55.4781    295.69        78      RE
# 191            long beach  33.7670 -118.1892    296.83        64      US
# 196             carnarvon -24.8667  113.6333    300.09        43      AU
# 201        margaret river -33.9500  115.0667    295.09        52      AU
# 211                 doaba  33.4244   70.7364    281.28        33      PK
# 223                gilmer  32.7287  -94.9424    284.49        37      US
# 268                kodiak  57.7900 -152.4072    271.88        64      US
# 273                laguna  38.4210 -121.4238    289.32        47      US
# 275              hamilton  39.1834  -84.5333    275.36        76      US
# 276        cabo san lucas  22.8909 -109.9124    298.49        65      MX
# 309  eldorado at santa fe  35.5264 -105.9347    278.12        52      US
# 338                  arar  30.9753   41.0381    291.16        25      SA
# 339        north tamworth -31.0778  150.9261    303.21        42      AU
# 368                 yasuj  30.6682   51.5880    273.90        51      IR
# 374                illizi  26.4833    8.4667    283.04        36      DZ
# 414                  ghat  24.9647   10.1728    284.97        38      LY
# 456              narrabri -30.3167  149.7833    304.00        43      AU
# 504              bethanie -26.4833   17.1500    292.60        35     NaN
# 523                 houma  29.5958  -90.7195    283.71        57      US
#
#      Max Temp C                    Hotel Name
# 1          7.53                Wildwood Hotel
# 7        -24.14                No hotel found
# 17        15.25               Shrawan ke Room
# 109       14.24                   Hantam Huis
# 130       28.02                  Motel du Lac
# 183       27.98                   Casa Blanca
# 184       22.04                 Les Lataniers
# 190       22.54                  Tropic Hotel
# 191       23.68                        Westin
# 196       26.94               Carnarvon Motel
# 201       21.94                No hotel found
# 211        8.13                No hotel found
# 223       11.34                No hotel found
# 268       -1.27          Russian Heritage Inn
# 273       16.17  Holiday Inn Express & Suites
# 275        2.21             North Vista Manor
# 276       25.34                 Comfort Rooms
# 309        4.97                No hotel found
# 338       18.01            دار أوتيل Dar Otel
# 339       30.06           Imperial Brew House
# 368        0.75         خوابگاه دانشجویی آمود
# 374        9.89                        بوناقة
# 414       11.82                   فندق تاسيلي
# 456       30.85               Aaron Inn Motel
# 504       19.45          Bethanie Guest House
# 523       10.56   Courtyard by Marriott Houma

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
mapplot2 = hotel_df.hvplot.points("Lng", "Lat", geo = True, tiles = "OSM", color = "City", 
                                  hover_cols=['City', 'Max Temp', 'Hotel Name', 'Humidity', 'Country'])
mapplot2


# Display the map
# YOUR CODE HERE
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Hotel Name,Humidity,Country)
